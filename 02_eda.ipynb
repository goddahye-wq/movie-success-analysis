# %% [markdown]
# # 02. 탐색적 데이터 분석 (EDA)
#
# 수집된 데이터를 바탕으로 '왕과 사는 남자'의 성공 요인을 시각화하고 분석합니다.
# - 관객수 추이 비교
# - 장르 보급력 및 시장 점유율 분석
# - 관객 평점 및 리뷰 키워드 분석

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import koreanize_matplotlib

# 데이터 로드 (예시)
# df = pd.read_csv('../data/processed/movie_data.csv')
print("EDA 시작 준비 완료")
