# %% [markdown]
# # 01. 데이터 수집 (Data Collection)
#
# 이 노트북에서는 분석에 필요한 영화 데이터를 수집합니다.
# - KOBIS API: 박스오피스 데이터
# - TMDB API: 영화 메타데이터 (포스터, 개요 등)
# - 네이버/다음 영화: 리뷰 및 평점 데이터 (Scraping)

# %%
import pandas as pd
import requests
import os
from bs4 import BeautifulSoup
import koreanize_matplotlib

# API 키 설정 (필요 시)
KOBIS_API_KEY = "YOUR_KOBIS_API_KEY"
TMDB_API_KEY = "YOUR_TMDB_API_KEY"

# %% [markdown]
# ## 1. 대상 영화 정보 정의

# %%
movies = [
    {"title": "왕과 사는 남자", "release_date": "2026-03-XX"},
    {"title": "명량", "release_date": "2014-07-30"},
    {"title": "사도", "release_date": "2015-09-16"},
    {"title": "기생충", "release_date": "2019-05-30"}
]

df_movies = pd.DataFrame(movies)
df_movies
